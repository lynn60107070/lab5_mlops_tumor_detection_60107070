# %%
import pandas as pd

df = pd.read_parquet("features.parquet")
print(df.shape)
print(df.head())
# Out:
# (253, 170)
#   image_id  label  orig_contrast_0  orig_contrast_45  orig_contrast_90  \
# 0       Y1      1       241.794834        467.362794        258.303123
# 1      Y10      1       210.688103        405.249312        204.421861
# 2     Y100      1       130.064143        199.075230         78.749711
# 3     Y101      1       573.710025       1057.388329        519.148667
# 4     Y102      1        44.084566         74.943466         37.173267
#
#    orig_contrast_135  orig_dissimilarity_0  orig_dissimilarity_45  \
# 0         428.517262              7.955461              11.135365
# 1         408.369098              6.999371              10.761181
# 2         187.581891              5.373985               6.715322
# 3        1079.370768              6.774725               9.782579
# 4          77.989615              4.037239               5.540470
#
#    orig_dissimilarity_90  orig_dissimilarity_135  ...  prewitt_ASM_90  \
# ...
